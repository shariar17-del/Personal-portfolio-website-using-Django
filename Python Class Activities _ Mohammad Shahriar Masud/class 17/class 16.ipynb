# %%
import numpy as np

my_list = [5, 10, 15, 20, 25]

my_array = np.array(my_list)

print(my_array)
# Out:
# [ 5 10 15 20 25]

# %%
import numpy as np
my_list = [[1, 2], [3, 4], [5, 6]]
my_2d_array = np.array(my_list)
print(my_2d_array)
# Out:
# [[1 2]
#  [3 4]
#  [5 6]]

# %%
import numpy as np
zeros_matrix = np.zeros((3, 3))

# Print the matrix
print(zeros_matrix)
# Out:
# [[0. 0. 0.]
#  [0. 0. 0.]
#  [0. 0. 0.]]
